# %% [markdown]
# # 1. Importing Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2 .Data Exploration:

# %%
# 1. Loading and reading the data:

df = pd.read_csv("C:\\Users\\lordo\\DATASETS FOR EDA\\BankChurners.csv")

# %%
# 2. Reading the first five rows:

df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
# 3. checking data shape(rows and columns)

df.shape
# Out:
# (10127, 21)

# %%
# 4. Columns name and their overview:

df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
# Column	           Meaning

# CLIENTNUM	       Unique ID for each customer.
# Attrition_Flag	   Whether the customer has churned ("Attrited Customer") or is still active ("Existing Customer").
# Customer_Age	   Age of the customer.
# Gender	           Gender of the customer (Male/Female).
# Dependent_count	   Number of dependents (like kids or family members relying on the customer).
# Education_Level	   Customer’s highest education (like High School, Graduate, etc.).
# Marital_Status	   Whether the customer is married, single, divorced, etc.
# Income_Category	   Customer's income range (like <$40K, $40K–$60K, etc.).
# Card_Category	   Type of credit card the customer has (like Blue, Silver, Gold, Platinum).
# Months_on_book	   How many months the customer has been with the company (account age)  .

# Total_Relationship_Count	   Total number of products/accounts the customer has with the company.
# Months_Inactive_12_mon	       Number of months the customer was inactive in the last 12 months.
# Contacts_Count_12_mon	       Number of times the customer contacted customer service in the last 12 months.
# Credit_Limit	               Customer’s credit card limit.
# Total_Revolving_Bal	           Customer’s balance that is carried over month to month (not paid fully).
# Avg_Open_To_Buy	               Average available credit for making purchases (Credit Limit - Balance).
# Total_Amt_Chng_Q4_Q1	       Change in the total amount spent from Q4 to Q1 (relative change).
# Total_Trans_Amt	               Total amount of transactions made in the last 12 months.
# Total_Trans_Ct	               Total number of transactions made in the last 12 months.
# Total_Ct_Chng_Q4_Q1	           Change in the transaction count from Q4 to Q1 (relative change).
# Avg_Utilization_Ratio	       Ratio of the balance to the credit limit (how much of their credit the customer uses on average).

# %%
# 5. Checking columns datatypes:

df.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
# 6 Checking MISSING VALUES:

df.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# # 2. Statistical Analysis:

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# # 3. Data Visualisations:

# %% [markdown]
# # 1. Churn distribution

# %%
ax = sns.countplot(x='Attrition_Flag',data=df)
plt.title('Distribution of churned vs existing customers')

for p in ax.patches:
    count = p.get_height()
    ax.annotate(f'{count}', (p.get_x() + p.get_width() / 2., count),
                ha='center', va='bottom', fontsize=11)
    
plt.show()

# %%
# Insight : Out of 10127 total number of churned customers are: 1627:

# %% [markdown]
# # 2. Age distribution by Attrition Flag:

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Customer_Age',hue='Attrition_Flag',multiple='stack',bins=20)
plt.title("Age Distribution by Attrition Flag")
plt.show()

# %%
# Insight: The highest number of attrited customers appears around ages 38-53, 
# which could indicate that customers in their 40s are more likely to churn.

# %%
churned_df = df[df['Attrition_Flag'] == 'Attrited Customer']

most_common_ages = churned_df['Customer_Age'].mode()

print("Most frequent ages among churned customers:")
for age in most_common_ages:
    count = churned_df[churned_df['Customer_Age'] == age].shape[0]
    print(f"Age: {age}, Count: {count}")
# Out:
# Most frequent ages among churned customers:
# Age: 43, Count: 85
# Age: 48, Count: 85

# %% [markdown]
# # 3.Customer Churn By Gender:

# %%
ax = sns.countplot(data=df,x='Gender',hue='Attrition_Flag')

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', 
                (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='bottom', fontsize=10)

plt.title('Churn Count by Gender')
plt.xlabel('Gender')
plt.ylabel('churned')
plt.show(),

# churned female is more than churned male:
# Out:
# (None,)

# %%
# Insight: Churned Female customer are more than male:

# %% [markdown]
# # 4 .Total_Trans_ct vs Total_Trans_amt:

# %%
sns.scatterplot(data=df, x='Total_Trans_Ct', y='Total_Trans_Amt', hue='Attrition_Flag')
plt.title("total_trans_ct vs Total_Trans_amt")
plt.show()

# %%
# Insight:

# Relationship Between Transaction Count and Amount (Churned Customers)
# Among churned customers, the total transaction count ranges from 10 to 94, while the total transaction amount varies between 510 and 10,583.
# A clear trend is observed: as the transaction count increases, the total transaction amount also tends to increase.

# %%
# 1. What is the highest total_trans_amt and lowest_trans_amt among churned customer:

churned_df = df[df['Attrition_Flag']=='Attrited Customer']

max_trans_amt = churned_df['Total_Trans_Amt'].max()

min_trans_amt = churned_df['Total_Trans_Amt'].min()

print(f"Highest Total_Trans_Amt among churned customers: {max_trans_amt}")

print(f"Lowest Total_Trans_Amt among churned customers: {min_trans_amt}")
# Out:
# Highest Total_Trans_Amt among churned customers: 10583
# Lowest Total_Trans_Amt among churned customers: 510

# %%
# 2. what is the Highest and lowest total_trans_ct among churned customer:

churned_df = df[df['Attrition_Flag']=='Attrited Customer']

max_trans_ct = churned_df['Total_Trans_Ct'].max()

min_trans_ct = churned_df['Total_Trans_Ct'].min()

print(f"Highest Total_Trans_ct among churned customers: {max_trans_ct}")

print(f"Lowest Total_Trans_ct among churned customers: {min_trans_ct}")
# Out:
# Highest Total_Trans_ct among churned customers: 94
# Lowest Total_Trans_ct among churned customers: 10

# %%
# 3. What is the total_trans_amt associated with the highest and lowest total_trans_ct:

churned_df = df[df['Attrition_Flag'] == 'Attrited Customer']

max_trans_ct = churned_df['Total_Trans_Ct'].max()
min_trans_ct = churned_df['Total_Trans_Ct'].min()

print("Churned Customer(s) with Highest Total_Trans_Ct:")
print(churned_df[churned_df['Total_Trans_Ct'] == max_trans_ct][['CLIENTNUM', 'Total_Trans_Ct', 'Total_Trans_Amt']])

print("\nChurned Customer(s) with Lowest Total_Trans_Ct:")
print(churned_df[churned_df['Total_Trans_Ct'] == min_trans_ct][['CLIENTNUM', 'Total_Trans_Ct', 'Total_Trans_Amt']])
# Out:
# Churned Customer(s) with Highest Total_Trans_Ct:
#       CLIENTNUM  Total_Trans_Ct  Total_Trans_Amt
# 9733  711096633              94             8600
#
# Churned Customer(s) with Lowest Total_Trans_Ct:
#       CLIENTNUM  Total_Trans_Ct  Total_Trans_Amt
# 144   767712558              10              530
# 653   712979133              10              646
# 1867  711224733              10              695
# 2554  720693033              10              741

# %%
# 4. What is the total_trans_ct associated with the highest and lowest total_trans_amt:

churned_df = df[df['Attrition_Flag'] == 'Attrited Customer']

max_amt = churned_df['Total_Trans_Amt'].max()
min_amt = churned_df['Total_Trans_Amt'].min()

print("Churned Customer(s) with Highest Total_Trans_Amt:")
print(churned_df[churned_df['Total_Trans_Amt'] == max_amt][['CLIENTNUM', 'Total_Trans_Amt', 'Total_Trans_Ct']])

print("\nChurned Customer(s) with Lowest Total_Trans_Amt:")
print(churned_df[churned_df['Total_Trans_Amt'] == min_amt][['CLIENTNUM', 'Total_Trans_Amt', 'Total_Trans_Ct']])
# Out:
# Churned Customer(s) with Highest Total_Trans_Amt:
#       CLIENTNUM  Total_Trans_Amt  Total_Trans_Ct
# 9946  711460458            10583              75
#
# Churned Customer(s) with Lowest Total_Trans_Amt:
#      CLIENTNUM  Total_Trans_Amt  Total_Trans_Ct
# 243  708874533              510              24

# %%
# Transaction Behavior Insights for Churned Customers

# 1.The highest total transaction amount among churned customers is 10,583, associated with a transaction count of 75.

# 2.The lowest total transaction amount is 510, with a corresponding transaction count of 24.

# 3.The maximum number of transactions (Total_Trans_Ct) observed is 94, linked to a transaction amount of 8,600.

# 4.The minimum transaction count is 10, with associated transaction amounts of 530, 646, 695, and 741.

# %% [markdown]
# # 5. Avg utilisation ratio vs churn :

# %%
# Utilization Ratio Matters

# Higher average utilization ratio (spending more of their limit) might relate to churn (due to stress/debt).

# %%
# Insight:
# 1.The presence of outliers in the attrited groups indicates that some churned customers have remarkably high utilisation ratios :

#2.Higher utlisation relate to churn:
# Higher utlisation means the customer is using most of their credit limit, possibly due to financial need or poor cash flow:
# These customers may struggle to pay back , leading to account closure or churn:



# 3.Risk Management by the Bank:
# Banks track utilization ratios to monitor risk. If a customer consistently uses 80–100% of their credit, the bank may flag them as risky and either reduce benefits or terminate the relationship.

# Customer Frustration with Limits:
# Customers hitting their credit limit often may get frustrated if their limits aren’t raised, leading them to churn voluntarily.

# Fees and Interest Accumulation:
# High utilization often leads to higher interest charges or over-limit fees. This can lead to dissatisfaction and churn.

# Wider Spread:
# A wider spread among churned customers indicates inconsistency — some might churn due to low usage (inactive customers),
# while others churn due to very high usage (risk/stress).


# The bank should monitor customers with high utilization ratios and consider offering personalized credit counseling,
# limit adjustments, or rewards for healthy credit use to reduce churn risk.

# %%
sns.boxplot(data=df, x='Attrition_Flag', y='Avg_Utilization_Ratio')

plt.title('Avg Utilization Ratio vs Churn')
plt.xlabel('Customer Churn (Attrition_Flag)')
plt.ylabel('Average Utilization Ratio')

plt.show()

# %%
#  Insight: Transaction Count and Churn
#  Analysis of the Total_Trans_Ct (Total Transaction Count) shows that churned customers typically have lower
#  transaction activity compared to those who remain with the bank.

# Key Findings:

# Churned customers engage less frequently in transactions, indicating lower product engagement or inactive account behavior.

# Low usage may signal that the customer is not deriving enough value from the bank’s services or has shifted to a competitor.

#  Recommendation:
# Customers showing a decline in transaction frequency over time should be targeted with re-engagement strategies, such as:

# Personalized offers

# Notifications of benefits

# Reminders about inactive services

#  Insight: Age and Churn Patterns
# From the Customer_Age feature, we observe that:

# Churn is higher in certain age brackets, particularly among middle-aged and older customers.

# This could reflect changing financial goals, reduced borrowing needs, or a preference for simpler banking experiences.

# Key Trends:

# Younger customers (e.g., 25–35) show higher engagement and lower churn.

# Customers over 55 may be more likely to churn, possibly due to retirement-related account changes or switching to conservative financial products.

# Recommendation:
# Develop age-tailored engagement strategies:

# For older customers: Offer simplified banking options, better interest products, or retirement services.

# For younger customers: Focus on digital services, rewards programs, and credit-building features.

# Would you like these insights compiled into a ready-to-use PDF or PowerPoint format summary?

# %%
# 1 Find out the number of customer who are spending more than average_utliation ratio:

# %%
attrited = df[df['Attrition_Flag'] == 'Attrited Customer']

Q1 = attrited['Avg_Utilization_Ratio'].quantile(0.25)
Q3 = attrited['Avg_Utilization_Ratio'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = attrited[(attrited['Avg_Utilization_Ratio'] < lower_bound) | 
                    (attrited['Avg_Utilization_Ratio'] > upper_bound)]

print("Number of customer who are spending more than avg utlisation ratio:", outliers.shape[0])
# Out:
# Number of customer who are spending more than avg utlisation ratio: 194

# %% [markdown]
# # 6 . Churn by Income Category:

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
churned_df = df[df['Attrition_Flag'] == 'Attrited Customer']

plt.figure(figsize=(10, 6))
ax = sns.countplot(data=churned_df, x='Income_Category', 
                   order=churned_df['Income_Category'].value_counts().index)
plt.title('Churned Customers by Income Category')
plt.xlabel('Income Category')
plt.ylabel('Count of Churned Customers')
plt.xticks(rotation=45)

for p in ax.patches:
    count = int(p.get_height())
    ax.annotate(f'{count}', (p.get_x() + p.get_width() / 2., count),
                ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Insight:
# customer who are earning less than $40k have the highest number of churn:(612)

# %% [markdown]
# # 7 Customer Churn By Martial Status:

# %%
# married and single have the nearly same name of customer with churn:

# %%
churned_df = df[df['Attrition_Flag'] == 'Attrited Customer']

plt.figure(figsize=(10, 6))
ax = sns.countplot(data=churned_df, x='Marital_Status', 
                   order=churned_df['Marital_Status'].value_counts().index)

plt.title('Churned Customers by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count ')

for p in ax.patches:
    height = int(p.get_height())
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 8. Customer Churn by Card Category:

# %%
# Insight:
# person with the platinum card have the highest number of number of churned customer:
# person with the silver car have the lowest number of churn:

# %%
card_category_churn = pd.crosstab(df['Card_Category'], df['Attrition_Flag'], normalize='index')

ax = card_category_churn.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='Set2')

for bar in ax.patches:
    width = bar.get_width()
    height = bar.get_height()
    x, y = bar.get_xy()
    
    if height > 0:
        ax.text(x + width / 2, y + height / 2,
                f'{height:.1%}',  # Convert to percentage
                ha='center', va='center', fontsize=10, color='black')

plt.title('Churn by Card Category')
plt.xlabel('Card Category')
plt.ylabel('Proportion of Customers')
plt.legend(title='Attrition Flag', loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Insight:
# person with the platinum card have the highest number of number of churned customer:(25%)
# person with the silver car have the lowest number of churn:(14.8%)

# %% [markdown]
# # 9 . Utilisation Ratio vs Credit limit:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Credit_Limit', y='Avg_Utilization_Ratio', hue='Attrition_Flag')
plt.title('Utilization Ratio vs Credit Limit')
plt.xlabel('Credit Limit')
plt.ylabel('Avg Utilization Ratio')
plt.show()

# %%
# Overall, the plot indicates that customers with higher credit limits typically utilize a smaller portion of their available credit,
# aligning with common credit behavior patterns.

# %%
# find out the customer numer of churn customer with the credit limit less than 5000
# and average utlisation ration less than 0.2

# %%
# find out the number of customer with the credit limit less than 5000 and avg_utlisation ratio = 0:
# even some customers are there who bought the credit card but left the bank without even using it:

# %%
# customers with the higher credit limit with avg utlisation 0 left the bank
# and same in the case of person of low credit cart:

# %% [markdown]
# # 10 Inactive month vs Customer Churn:

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Months_Inactive_12_mon', hue='Attrition_Flag', kde=True)
plt.title('Months of Inactivity vs Churn')
plt.xlabel('Months Inactive')
plt.ylabel('Count of Customers')
plt.show()

# %%
# insight:
# numbers of customer who were inactive for 3 month and then left the bank:
# number of customer who were inactive less than one month and then left the bank:
# what could be the reason for it:

# %% [markdown]
# # 11 Total Transaction Amount vs Credit Limit

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Credit_Limit', y='Total_Trans_Amt', hue='Attrition_Flag')
plt.title('Total Transaction Amount vs Credit Limit')
plt.xlabel('Credit Limit')
plt.ylabel('Total Transaction Amount')
plt.show()

# %%
# INSIGHT:

# Some churned customer with the low credit limit but high total-_trnasaction amount;

# %% [markdown]
# # 12 customer activity vs churn:

# %%
#  Contacts_Count_12_mon:  Number of times the customer contacted customer service in the last 12 months.

activity_data = df[['Contacts_Count_12_mon', 'Total_Trans_Ct', 'Attrition_Flag']].groupby(['Attrition_Flag']).mean()
sns.heatmap(activity_data, annot=True, cmap='Blues')
plt.title('Customer Activity vs Churn')
plt.show()

# %%
# Insight:
# Churned customer have contacted more times to cusotmer service in comaprison to the existing customer:
